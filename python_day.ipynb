# %% [markdown]
# <a href="https://colab.research.google.com/github/Anirudh9247/dsa_project/blob/main/python_day.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x=10
for i in range (20,10,-2):
	x=x+2
	print("Hi")
for i in "Hi":
	print(x,end=" ")
# Out:
# Hi
# Hi
# Hi
# Hi
# Hi
# 20 20

# %%
z=3
for i in "island":
	z=z+1
s=z
for i in range(z):
	s=s+i
print(s)
# Out:
# 45

# %%
********* shape in rectangle

# %%
for i in range(8):
  print("*",end=" ")
print()
for j in range(6):
  print("*             *")

for k in range(8):
  print("*",end=" ")
print()
# Out:
# * * * * * * * *
# *             *
# *             *
# *             *
# *             *
# *             *
# *             *
# * * * * * * * *

# %%
a = int(input())
x=1
if(a%2!=0):
  for i in range(a):
    print(f" {a} * {x} = {a*x}")
    x=x+1
else:
  for i in range(10):
    print(f" {a} * {x} = {a*x}")
    x=x+1
# Out:
# 8
#  8 * 1 = 8
#  8 * 2 = 16
#  8 * 3 = 24
#  8 * 4 = 32
#  8 * 5 = 40
#  8 * 6 = 48
#  8 * 7 = 56
#  8 * 8 = 64
#  8 * 9 = 72
#  8 * 10 = 80

# %%
s=input()

s=s.split()
print(len(s))
# Out:
# i had left   america
# 4
